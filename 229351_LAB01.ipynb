# %% [markdown]
# <a href="https://colab.research.google.com/github/nattapongbam/Lab-stat1/blob/main/229351_LAB01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ปฏิบัติการครั้งที่ 1 กระบวนวิชา 229351 Statistical Learning for Data Science
#
# คำชี้แจง
#
# 1. ให้เริ่มทำปฏิบัติการจาก colab notebook ที่กำหนดให้ **เมื่อเสร็จแล้วให้ทำการ share** จากนั้นส่ง link มาใน mango canvas
#
# ในขั้นตอนแรก ขอให้ download ไฟล์ที่
#
# http://donlapark.pages.dev/229351/data/housing.csv

# %%
import pandas as pd #dataframes
import numpy as np #matrices
import matplotlib.pyplot as plt #for plotting

# %matplotlib inline

# !wget http://donlapark.pages.dev/229351/data/housing.csv

housing = pd.read_csv("housing.csv")

housing.head(10)
# Out:
# --2025-06-26 02:29:47--  http://donlapark.pages.dev/229351/data/housing.csv
# Resolving donlapark.pages.dev (donlapark.pages.dev)... 172.66.44.200, 172.66.47.56, 2606:4700:310c::ac42:2cc8, ...
# Connecting to donlapark.pages.dev (donlapark.pages.dev)|172.66.44.200|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://donlapark.pages.dev/229351/data/housing.csv [following]
# --2025-06-26 02:29:47--  https://donlapark.pages.dev/229351/data/housing.csv
# Connecting to donlapark.pages.dev (donlapark.pages.dev)|172.66.44.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1423529 (1.4M) [text/csv]
# Saving to: ‘housing.csv.1’
#
# housing.csv.1       100%[===================>]   1.36M  --.-KB/s    in 0.008s
#
# 2025-06-26 02:29:47 (164 MB/s) - ‘housing.csv.1’ saved [1423529/1423529]
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
# 5       413.0       193.0         4.0368            269700.0        NEAR BAY
# 6      1094.0       514.0         3.6591            299200.0        NEAR BAY
# 7      1157.0       647.0         3.1200            241400.0        NEAR BAY
# 8      1206.0       595.0         2.0804            226700.0        NEAR BAY
# 9      1551.0       714.0         3.6912            261100.0        NEAR BAY

# %% [markdown]
# ## Basic data exploration

# %%
housing.shape
# Out:
# (20640, 10)

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# Which variable has missing data?

# %%
housing = housing.dropna()

# %%
housing.info()

# %%
housing.describe()

# %% [markdown]
# ## Exercise 1
#
# 1. Download ไฟล์ข้อมูลที่
#   http://donlapark.pages.dev/229351/data/Advertising.csv
#   ซึ่งเป็นข้อมูลของผลการขายสินค้าอย่างหนึ่ง (Sales) กับการโฆษณาผ่านทาง TV, Radio, Newspaper
# 2. สร้าง dataframe ชื่อว่า **Ads** โดยใช้ข้อมูลชุดนี้
# 3. ดูข้อมูล 5 แถวแรกของ `Ads`
# 4. ตรวจสอบว่ามีข้อมูลที่หายไปหรือไม่
# 5. แสดงค่าสถิติพรรณนา (Descriptive statistics) ของตัวแปรต่างๆ

# %%
Ads = pd.read_csv("housing.csv")

# %%
Ads.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
Ads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
Ads.dropna()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20433 rows x 10 columns]

# %%
Ads.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %% [markdown]
# Your answers here:

# %% [markdown]
# ## Calling, indexing & modifying dataframes

# %%
# calling a column

housing['ocean_proximity']

# %% [markdown]
# `ocean_proximity` is categorical. Let's count its values.

# %%
housing["ocean_proximity"].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9034
# INLAND        6496
# NEAR OCEAN    2628
# NEAR BAY      2270
# ISLAND           5
# Name: count, dtype: int64

# %% [markdown]
# ## Basic statistics of a variable

# %%
print("Mean: ",housing["total_rooms"].mean())
print("Standard deviation: ",housing["total_rooms"].std())
print("Maximum: ",housing["total_rooms"].max())
print("Minimum: ",housing["total_rooms"].min())
# Out:
# Mean:  2636.5042333480155
# Standard deviation:  2185.269566977597
# Maximum:  39320.0
# Minimum:  2.0

# %%
housing[["longitude", "latitude", "housing_median_age"]]

# %%
housing.loc[0]

# %% [markdown]
# ## Extracting a subset of dataframe

# %%
housing.loc[1:3, ["longitude","latitude"]]

# %%
housing.iloc[2:5,:]

# %% [markdown]
# ## Selecting rows based on conditions

# %%
housing[housing['latitude']>=40]

# %%
housing[(housing['longitude']>-122) & (housing['latitude']>=40)]

# %% [markdown]
# ## Exercise 2
#
# ในข้อต่อไปนี้ ให้นับแถวและคอลัมน์เริ่มจาก 0
# 1. แสดงค่าสูงสุดของข้อมูลที่อยู่ในแถวที่ 200-400 ของตัวแปร `total_bedrooms`
# 2. แสดง 3 คอลัมน์สุดท้ายของพื้นที่ที่มีจำนวนห้องนอน (`total_bedrooms`) มากกว่า 900 ห้อง

# %%
housing.loc[200:401, 'total_bedrooms'].max()
# Out:
# 2048.0

# %%
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20433 rows x 10 columns]

# %%
housing.loc[housing['total_bedrooms'] > 900, ['median_income','median_house_value','ocean_proximity']]
# Out:
#        median_income  median_house_value ocean_proximity
# 1             8.3014            358500.0        NEAR BAY
# 95            2.0096            130000.0        NEAR BAY
# 96            2.8345            183800.0        NEAR BAY
# 98            1.2185            170000.0        NEAR BAY
# 99            2.6104            193100.0        NEAR BAY
# ...              ...                 ...             ...
# 20563         3.1250            132500.0          INLAND
# 20567         5.3064            165000.0          INLAND
# 20569         4.1997            133400.0          INLAND
# 20603         1.3375             59600.0          INLAND
# 20629         2.0943            108300.0          INLAND
#
# [2382 rows x 3 columns]

# %% [markdown]
# ## Plotting

# %%
housing.hist(bins=20, figsize=(15,15))
plt.show()

# %%
housing.head(3)

# %%
housing.plot.scatter(x="longitude", y="latitude");

# %%
housing.plot.scatter(x="longitude", y="latitude", alpha=0.1)

# %%
corr_matrix = housing.iloc[:, :-1].corr()

corr_matrix
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.099773    0.055310      -0.015176
# latitude                 -0.066983   -0.108785   -0.071035      -0.079809
# housing_median_age       -0.320451   -0.296244   -0.302916      -0.119034
# total_rooms               0.930380    0.857126    0.918484       0.198050
# total_bedrooms            1.000000    0.877747    0.979728      -0.007723
# population                0.877747    1.000000    0.907222       0.004834
# households                0.979728    0.907222    1.000000       0.013033
# median_income            -0.007723    0.004834    0.013033       1.000000
# median_house_value        0.049686   -0.024650    0.065843       0.688075
#
#                     median_house_value
# longitude                    -0.045967
# latitude                     -0.144160
# housing_median_age            0.105623
# total_rooms                   0.134153
# total_bedrooms                0.049686
# population                   -0.024650
# households                    0.065843
# median_income                 0.688075
# median_house_value            1.000000

# %% [markdown]
# ### Grouping
#
# พิจารณา Anscombe dataset ข้างล่างนี้

# %%
import seaborn as sns

df = sns.load_dataset('anscombe')

# %%
df.head(3)
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58

# %%
groups = df.groupby('dataset')

# %%
groups

# %%
datasat_I = groups.get_group('I')
datasat_I.head(3)
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58

# %%
groups.max()
# Out:
#             x      y
# dataset
# I        14.0  10.84
# II       14.0   9.26
# III      14.0  12.74
# IV       19.0  12.50

# %% [markdown]
# ## Exercise 3
#
# 1. คำนวณค่า mean, standard deviation และ correlation matrix ของแต่ละกลุ่ม
# 2. สร้าง scatter plot ของแต่ละกลุ่มด้วย `groups.plot.scatter(...)`
# 3. จากข้อ 1 และข้อ 2 จงบอกว่าการศึกษาค่า summary statistics (mean, s.d., correlation) อย่างเดียวเพียงพอกับการศึกษาข้อมูลชุดหนึ่งหรือไม่ เพราะเหตุใด

# %%
groups = df.groupby('dataset').agg(['mean', 'std'])
groups
# Out:
#            x                   y
#         mean       std      mean       std
# dataset
# I        9.0  3.316625  7.500909  2.031568
# II       9.0  3.316625  7.500909  2.031657
# III      9.0  3.316625  7.500000  2.030424
# IV       9.0  3.316625  7.500909  2.030579

# %%
groups = df.groupby('dataset').mean()
groups
# Out:
#            x         y
# dataset
# I        9.0  7.500909
# II       9.0  7.500909
# III      9.0  7.500000
# IV       9.0  7.500909

# %%
groups_1 = df.groupby('dataset').std()
groups_1
# Out:
#                 x         y
# dataset
# I        3.316625  2.031568
# II       3.316625  2.031657
# III      3.316625  2.030424
# IV       3.316625  2.030579

# %%
groups_2 = df.groupby('dataset').corr()
groups_2
# Out:
#                   x         y
# dataset
# I       x  1.000000  0.816421
#         y  0.816421  1.000000
# II      x  1.000000  0.816237
#         y  0.816237  1.000000
# III     x  1.000000  0.816287
#         y  0.816287  1.000000
# IV      x  1.000000  0.816521
#         y  0.816521  1.000000

# %%
groups
# Out:
#            x                   y
#         mean       std      mean       std
# dataset
# I        9.0  3.316625  7.500909  2.031568
# II       9.0  3.316625  7.500909  2.031657
# III      9.0  3.316625  7.500000  2.030424
# IV       9.0  3.316625  7.500909  2.030579

# %%
groups = df.groupby('dataset')

# %%
groups.plot(kind='scatter', x='x', y='y')
# Out:
# dataset
# I      Axes(0.125,0.11;0.775x0.77)
# II     Axes(0.125,0.11;0.775x0.77)
# III    Axes(0.125,0.11;0.775x0.77)
# IV     Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %% [markdown]
# ข้อ3
# ตอบ การศึกษาค่า summary statistics เพียงอย่างเดียวไม่เพียงพอกับการศึกษาชุดข้อมูล เพราะ จากการศึกษาพบว่าค่าเฉลี่ย และ ค่าส่วนเบี่ยงเบนมาตรฐานของข้อมูลที่แยกกลุ่มมีค่าที่ใกล้เคียงกัน แต่เมื่อนำข้อมูลมาplot แยกกลุ่มพบว่าข้อมูลในแต่ละกลุ่มมีลักษณะการกระจายที่แตกต่างกัน
