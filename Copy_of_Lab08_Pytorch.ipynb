# %% [markdown]
# <a href="https://colab.research.google.com/github/nattapongbam/229352-StatisticalLearning681/blob/main/Copy_of_Lab08_Pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Statistical Learning for Data Science 2 (229352)
# #### Instructor: Donlapark Ponnoprat
#
# #### [Course website](https://donlapark.pages.dev/229352/)
#
# ## Lab #8

# %% [markdown]
# There are several deep learning frameworks in Python.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c6/PyTorch_logo_black.svg/2560px-PyTorch_logo_black.svg.png" width="100"/>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<img src="https://upload.wikimedia.org/wikipedia/commons/2/2d/Tensorflow_logo.svg" width="40"/><img src="https://assets-global.website-files.com/621e749a546b7592125f38ed/62277da165ed192adba475fc_JAX.jpg" width="100"/>
#
# In this Lab, we will use PyTorch

# %%
import numpy as np

import torch

# %% [markdown]
# # Tensor basics

# %% [markdown]
# ## Basic tensor creation

# %% [markdown]
# ### Creating a scalar (1D) tensor

# %%
a = torch.tensor([1.])
a
# Out:
# tensor([1.])

# %% [markdown]
# ### Convert a tensor to scalar

# %%
b = a[0].item()
b
# Out:
# 1.0

# %% [markdown]
# ### Creating 2D tensor

# %%
c = torch.tensor([[1., 2.], [3., 4.]])
c
# Out:
# tensor([[1., 2.],
#         [3., 4.]])

# %% [markdown]
# ## Tensor and Numpy

# %% [markdown]
# ### Convert from tensor to numpy array

# %%
d = c.numpy()
d
# Out:
# array([[1., 2.],
#        [3., 4.]], dtype=float32)

# %% [markdown]
# ### Convert from numpy array to tensor

# %%
f = torch.from_numpy(d)
f
# Out:
# tensor([[1., 2.],
#         [3., 4.]])

# %% [markdown]
# ## PyTorch and GPU

# %% [markdown]
# check if GPU is available

# %%
torch.cuda.is_available()
# Out:
# True

# %%
c = c.cuda()
c
# Out:
# tensor([[1., 2.],
#         [3., 4.]], device='cuda:0')

# %%
e = c.cpu().numpy()
e
# Out:
# array([[1., 2.],
#        [3., 4.]], dtype=float32)

# %% [markdown]
# ## Basic operations

# %%
c * 2
# Out:
# tensor([[2., 4.],
#         [6., 8.]])

# %%
c - 1
# Out:
# tensor([[0., 1.],
#         [2., 3.]])

# %% [markdown]
# ### Matrix multiplication

# %%
A = torch.tensor([[4, 5], [8, 9]])
B = torch.tensor([[1, 4], [7, 8]])

torch.matmul(A, B)
# Out:
# tensor([[ 39,  56],
#         [ 71, 104]])

# %%
torch.mm(A, B)
# Out:
# tensor([[ 39,  56],
#         [ 71, 104]])

# %%
A @ B
# Out:
# tensor([[ 39,  56],
#         [ 71, 104]])

# %% [markdown]
# ### Matrix transpose

# %%
A.t()
# Out:
# tensor([[4, 8],
#         [5, 9]])

# %% [markdown]
# ## Creating a specific type of tensor

# %%
a = torch.zeros(1, 2, 3)
a
# Out:
# tensor([[[0., 0., 0.],
#          [0., 0., 0.]]])

# %%
b = torch.ones(1, 2, 3)
b
# Out:
# tensor([[[1., 1., 1.],
#          [1., 1., 1.]]])

# %%
I = torch.eye(3)
I
# Out:
# tensor([[1., 0., 0.],
#         [0., 1., 0.],
#         [0., 0., 1.]])

# %%
R1 = torch.rand(2, 3)
R1
# Out:
# tensor([[0.2939, 0.9558, 0.8495],
#         [0.3676, 0.0840, 0.6289]])

# %%
R2 = torch.randn(2, 3)
R2
# Out:
# tensor([[ 0.3655,  0.0039,  0.0822],
#         [ 0.8159, -0.0033, -0.3589]])

# %%
a = torch.arange(6)
a
# Out:
# tensor([0, 1, 2, 3, 4, 5])

# %% [markdown]
# ## Tensor's shape

# %%
R1.shape
# Out:
# torch.Size([2, 3])

# %% [markdown]
# ### Checking the shape of a tensor

# %%
u = torch.arange(6)
u.shape
# Out:
# torch.Size([6])

# %% [markdown]
# ### Changing the shape of a tensor

# %%
v = u.reshape(2, 3)
v.shape
# Out:
# torch.Size([2, 3])

# %%
w = u.view(3, 2)
w
# Out:
# tensor([[0, 1],
#         [2, 3],
#         [4, 5]])

# %% [markdown]
# In general, use `reshape`, but if you are worried about the memory usage, use `view`.

# %% [markdown]
# ### Stacking and concatenating tensors

# %%
a = torch.arange(4)
b = torch.arange(4) + 1

c = torch.stack([a, b], axis=0)
c
# Out:
# tensor([[0, 1, 2, 3],
#         [1, 2, 3, 4]])

# %%
d = torch.stack([a, b], axis=1)
d
# Out:
# tensor([[0, 1],
#         [1, 2],
#         [2, 3],
#         [3, 4]])

# %%
# concatenate
e = torch.cat([a, b], axis=0)
e # มิติเท่าเดิม
# Out:
# tensor([0, 1, 2, 3, 1, 2, 3, 4])

# %%
display(a,b)
# Out:
# tensor([0, 1, 2, 3])
# tensor([1, 2, 3, 4])

# %%
f = torch.cat([a.reshape(2, 2), b.reshape(2, 2)], axis=0)
f
# Out:
# tensor([[0, 1],
#         [2, 3],
#         [1, 2],
#         [3, 4]])

# %% [markdown]
# ### Squeezing a tensor (removing an extra dimension)

# %%
A = torch.zeros(1, 2, 3)
B = A.squeeze()
B
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %%
C = B.unsqueeze(axis=0)
C
# Out:
# tensor([[[0., 0., 0.],
#          [0., 0., 0.]]])

# %% [markdown]
# ### Unsqueezing a tensor (adding an extra dimension)

# %%
# H.shape = (6, )

# %% [markdown]
# ## Indexing

# %%
P = torch.arange(12).reshape(3,4)
print(P)
print(P[0])
print(P[:, 0])
print(P[-1])
print(P[:, -1])
print(P[-2:])
print(P[:, -2:])

# %%
torch.inverse(torch.tensor([[1., 2.], [3., 4.]]))
# Out:
# tensor([[-2.0000,  1.0000],
#         [ 1.5000, -0.5000]])

# %% [markdown]
# # Exercise
#
# In this exercise, we will simulate data to perform linear regression with 200 rows and 7 variables.
#
# 1. Create three random $N(0,1)$ tensors: `X`, `b` and `e` with `X.shape = (200, 7)`, `b.shape = (8, 1)` and `e.shape = (200, 1)` respectively.
# 2. Create a tensor that contains only 1's with shape `(200, 1)`.
# 3. Modify tensor `X` by adding the tensor in 2. as the first column.
# 4. Compute `y` using the following formula:
# $$ y = Xb + e $$.
# 5. Fit a linear regression to the data `X` and `y` and obtain a tensor of estimated coefficient `b_hat`. The formula for `b_hat` is given by:
# $$ \hat{b} = (X^TX)^{-1}X^Ty $$
# Note: use `torch.inverse(...)` to calculate the inverse
# 6. Compute the predictions `y_hat`, given by:
# $$ \hat{y} = X\hat{b} $$
# 7. Convert both `y` and `y_hat` from tensor to Numpy array and calculate MSE:
# $$ MSE = \frac{1}{200}\sum_{i=1}^{200} (y_i - \hat{y}_i)^2 $$

# %%
# X = torch.tensor([[2, 3, 2], [4, 6, 7], [7, 2, 4]])
# print(X)

# X = torch.tensor([[1, 2, 3, 2], [1, 4, 6, 7], [1, 7, 2, 4]])
# print(X)

# %%
X = torch.randn(200, 7)
b = torch.randn(8, 1)
e = torch.randn(200, 1)

# %%
one = torch.ones(200, 1)

# %%
X
# Out:
# tensor([[ 1.7017,  1.8814, -2.2282,  ...,  1.2352,  0.0247,  0.0911],
#         [-0.1980,  0.2510, -1.3084,  ...,  0.7970,  0.0662, -0.8002],
#         [ 0.7745,  0.9387,  0.4498,  ...,  0.0834, -0.8303,  2.2198],
#         ...,
#         [ 0.3705, -0.1042,  0.3133,  ..., -1.2909, -1.2308, -0.5224],
#         [-1.0014,  0.3083, -0.0410,  ..., -0.8305, -0.6998,  0.5144],
#         [-0.5031,  1.4989, -0.7130,  ..., -0.0339,  0.0478,  0.6068]])

# %%
X = torch.cat([one, X], axis=1)
X
# Out:
# tensor([[ 1.0000,  1.7017,  1.8814,  ...,  1.2352,  0.0247,  0.0911],
#         [ 1.0000, -0.1980,  0.2510,  ...,  0.7970,  0.0662, -0.8002],
#         [ 1.0000,  0.7745,  0.9387,  ...,  0.0834, -0.8303,  2.2198],
#         ...,
#         [ 1.0000,  0.3705, -0.1042,  ..., -1.2909, -1.2308, -0.5224],
#         [ 1.0000, -1.0014,  0.3083,  ..., -0.8305, -0.6998,  0.5144],
#         [ 1.0000, -0.5031,  1.4989,  ..., -0.0339,  0.0478,  0.6068]])

# %%
y = X @ b + e
y

# %%
b_hat = torch.inverse(X.t() @ X) @ X.t() @ y
b_hat
# Out:
# tensor([[-0.3184],
#         [-1.1671],
#         [ 0.0386],
#         [-0.1986],
#         [-0.3073],
#         [-1.0052],
#         [-0.0847],
#         [ 2.3196]])

# %%
y_hat = X @ b_hat
y_hat

# %%
y = y.numpy()
y_hat = y_hat.numpy()

# %%
MSE = (1/200) * (np.sum((y - y_hat)**2))
MSE
# Out:
# np.float32(1.004545)
